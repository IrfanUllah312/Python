# %% [markdown]
# # PROBLEM 1

# %%
account=int(input("Enter Your Account Number:"))

services=input("Enter your  Service ")



due_reg=10
due_pre=25


if (services=="REG" or services=="reg" ):
     minutes=int(input("Enter Number of Minutes the service used :"))
     if ( minutes <=50):
             
             print("AccountNumber : ",account)
             print("Type of Service :",services)
             print("Number of minutes telephone used",minutes)
             print("Amount Due in Dollars ",due_reg)
     else:
          sub=minutes-50
          sub=sub*0.20
          due_r=due_reg + sub 

          print("Account :",account)
          print("Type of Service:",services)
          print("Number of minutes telephone used:",minutes)
          print("Amount Due in Dollars :",due_reg)


    

if (services=='Pre' or services =='pre'):
    day=int(input("Enter Minutes between 6 Am to 6 Pm "))
    night=int(input("Enter Minutes between 6 Pm to 6 Am "))


    if( day !=0 and day > 75):

        sub=day-75
        sub=sub*0.10
        due_pre= due_pre +sub

    if(night !=0 and night >100):

        sub=night-100
        sub=sub*0.05
        due_pre = due_pre +sub
    
    print("Account ",account)
   
    print("Type of Service ",services)
    
    print("Number of minutes telephone used ",day+night)
    
    print("Amount Due in Dollars ",due_pre)

# %% [markdown]
# # PROBLEM 2

# %%
import random
random= random.randint(0,30)
money=int(input("|Enter money to invest :"))

guess=int(input("|YOUR GUESS Number IS : "))

wins=0
if ( guess==random):
    #Even 
    if(guess %2==0):

        wins +=2
    

    if(guess ==10 or guess == 20 or guess==30):

        wins +=3

    if(guess ==2,guess == 3, guess ==5, guess ==7, guess ==11, guess ==13, guess ==17, guess ==19, guess ==23, guess ==29):
        wins +=5


    if(guess < 5  and guess >=0 ):
        wins +=2

        print("Payout ",money*wins)
else:
    
    print("|incorrect guess           |")
    print("|TRY AGAIN !!!!            |")
print("|THE RANDOM NUMBER IS :",random,"|")

# %% [markdown]
# # PROBLEM 3   ( A )

# %%
num=int(input("ENTER 4 DIGETS NUMBER :"))


A=num//1000
a=num%1000

B=a//100
b=a%100

C=b//10
c=b%10

D=c//1
d=c%1

A2=(A+7)%10
B2=(B+7)%10
C2=(C+7)%10
D2=(D+7)%10

# now swep the values
# s=""
s=A2
A2=C2
C2=s

# x=""
x=B2
B2=D2
D2=x

# enc_digit=A2,B2,C2,D2
# enc_diget=(A2*1000)+(B2*100)+(C2*10)+(D2*1)

print(A2,B2,C2,D2)

# %% [markdown]
# # PROBLEM 3( B )

# %%
enc_diget=int(input(" ENTER THE ENCRYPTE FOUR_DIGIT INTEGER: "))

A=enc_diget//1000
a=enc_diget%1000

B=a//100
b=a%100

C=b//10
c=b%10

D=c//1
d=c%1

A2=(A-7)%10
B2=(B-7)%10
C2=(C-7)%10
D2=(D-7)%10

# now swep the values
s=""
s=A2
A2=C2
C2=s

x=""
x=B2
B2=D2
D2=x

org=(A2*1000)+(B2*100)+(C2*10)+(D2*1)


print("THE ORIGNAL VALUE IS :",org)

# %% [markdown]
# # PROBLEM 4

# %%
current_pop = 231.4 #million  
growth_r = 1.8  


year = 1
pop = current_pop


print("Year\t\tPop (million)\tYearly Increase (Million)")
print("-" * 48)


for year in range(2023, 2099):
    
    
    increase = pop * growth_r/ 100  


    pop += increase

    print(f"{year:4d}\t\t{pop:10.3f}\t\t{increase:10.3f}")

double_year = int(current_pop * 2 / increase)

print(f"\nThe world population is projected to double in {double_year}.")

# %% [markdown]
# # (add_coffee_record.py)

# %%
# This program adds coffee inventory records to
# the coffee.txt file.
def main():
     # Create a variable to control the loop.
    another= 'y'
    
    # Open the coffee.txt file in append mode.
    coffee_file = open('coffee.txt', 'a')

 # Add records to the file.
    while another == 'y' or another == 'Y':
        
# Get the coffee record data.
       print('Enter the following coffee data:')
       descr = input('Description: ')
    qty = int(input('Quantity (in pounds): '))

# Append the data to the file.
    coffee_file.write(descr + '\n')
    coffee_file.write(str(qty) + '\n')

# Determine whether the user wants to add
# another record to the file.
    print('Do you want to add another record?')
    another  = input('Y = yes, anything else = no: ')
# Close the file.
    coffee_file.close()
print('Data appended to coffee.txt.')
# Call the main function.
main()
# Out:
# Data appended to coffee.txt.
# Enter the following coffee data:

# %% [markdown]
# # (show_coffee_records.py)

# %%
# This program displays the records in the
# coffee.txt file.
def main():
  # Open the coffee.txt file.
    coffee_file = open('coffee.txt', 'r')
 
  # Read the first record's description field.
    descr = coffee_file.readline()

 # Read the rest of the file.
    while descr != '':
        
# Read the quantity field.
        qty = float(coffee_file.readline())

 # Strip the \n from the description.
        descr = descr.rstrip('\n')

 # Display the record.
        print('Description:', descr)
        print('Quantity:', qty)

 # Read the next description.
        descr= coffee_file.readline()

 # Close the file.
        coffee_file.close()

# Call the main function.
main()

# %% [markdown]
# # (search_coffee_records.py)

# %%
 # This program allows the user to search the
  # coffee.txt file for records matching a
  # description.

def main():
 # Create a bool variable to use as a flag.
      found = False

 # Get the search value.
      search = input('Enter a description to search for: ')

 # Open the coffee.txt file.
      coffee_file = open('coffee.txt', 'r')

 # Read the first record's description field.
      descr = coffee_file.readline()
 
 # Read the rest of the file.
while descr != '':
        
    
 # Read the quantity field.
        qty = float(coffee_file.readline())

 # Strip the \n from the description.
        descr = descr.rstrip('\n')

 # Determine whether this record matches
 # the search value.
        if descr == search:
            print('Description:', descr)
            print('Quantity:', qty)
            print()
 # Set the found flag to True.
            found = True

 # Read the next description.
        descr = coffee_file.readline()

 # Close the file.
        coffee_file.close()

 # If the search value was not found in the file
 # display a message.
if not found:
    print('That item was not found in the file.')
# Out:
#   Cell In[15], line 45
#     if != found:
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## (modify_coffee_records.py)

# %%
# This program allows the user to modify the quantity
# in a record in the coffee.txt file.
descr = ""
import os    # Needed for the remove and rename functions
 
def main():
# Create a bool variable to use as a flag.
    found = False

# Get the search value and the new quantity.
    search = input('Enter a description to search for: ')
    new_qty = int(input('Enter the new quantity: '))

# Open the original coffee.txt file.
    coffee_file = open('coffee.txt', 'r')

# Open the temporary file.
    temp_file = open('temp.txt', 'w')

 # Read the first record's description field.
    descr = coffee_file.readline()

 # Read the rest of the file
while descr != '':
    
 # Read the quantity field.
      qty = float(coffee_file.readline())

 # Strip the \n from the description.
      descr = descr.rstrip('\n')

    # Write either this record to the temporary file,
    # or the new record if this is the one that is
    # to be modified.
      if descr == search:
        
    # Write the modified record to the temp file.
          temp_file.write(descr + '\n')
          temp_file.write(str(new_qty) + '\n')

 # Set the found flag to True.
          found = True
      else:
        
 # Write the original record to the temp file.
        temp_file.write(descr + '\n')
        temp_file.write(str(qty) + '\n')

 # Read the next description.
      descr = coffee_file.readline()

 # Close the coffee file and the temporary file.
    coffee_file.close()
    temp_file.close()

 # Delete the original coffee.txt file.
os.remove('coffee.txt')

 # Rename the temporary file.
os.rename('temp.txt', 'coffee.txt')

 # If the search value was not found in the file
 # display a message.
if found:
     print('The file has been updated.')
else:
    print('That item was not found in the file.')

 # Call the main function.
main()
# Out:
#   File <tokenize>:53
#     coffee_file.close()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## (delete_coffee_record.py)

# %%
# This program allows the user to delete
# a record in the coffee.txt file.

import os # Needed for the remove and rename functions
 
def main():
    
# Create a bool variable to use as a flag.
    found = False
 
  # Get the coffee to delete.
    search = input('Which coffee do you want to delete? ')
# Open the original coffee.txt file.
    coffee_file = open('coffee.txt', 'r')

# Open the temporary file.
    temp_file = open('temp.txt', 'w')

 # Read the first record's description field.
    descr = coffee_file.readline()
    # Read the rest of the file.
    while descr != '':
        
 # Read the quantity field.
        qty = float(coffee_file.readline())

 # Strip the \n from the description.
        descr = descr.rstrip('\n')

 # If this is not the record to delete, then
 # write it to the temporary file.
        if descr != search:
            
 # Write the record to the temp file.
            temp_file.write(descr + '\n')
            temp_file.write(str(qty) + '\n')
        else:
 # Set the found flag to True.
             found = True

 # Read the next description.
        descr = coffee_file.readline()

 # Close the coffee file and the temporary file.
    coffee_file.close()
    temp_file.close()

 # Delete the original coffee.txt file.
    os.remove('coffee.txt')

 # Rename the temporary file.
    os.rename('temp.txt', 'coffee.txt')

 # If the search value was not found in the file
 # display a message.
    if found:
          print('The file has been updated.')
    else:
        print('That item was not found in the file.')

 # Call the main function.
main()
